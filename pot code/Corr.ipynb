# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

nwdf = pd.read_csv('nwdf.csv', index_col=[0])

# %%
g = sns.heatmap(nwdf[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"]].corr(),
                annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
sns.set(style="ticks")
sns.pairplot(nwdf, kind="reg")
plt.show()
